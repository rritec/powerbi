# %% [markdown]
# 1. Create **Snowflake** data warehouse
#     https://docs.snowflake.com/en/user-guide/getting-started-tutorial.html#snowflake-in-20-minutes
# 1. Open PBI Desktop
# 1. Connect snowflake
